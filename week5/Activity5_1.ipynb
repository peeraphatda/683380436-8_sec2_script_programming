# %% [markdown]
# Where would you use a dictionary in a game? (e.g., player inventory, character stats)

# %% [markdown]
# Ans. เพราะข้อมูลตัวละครหรือไอเทมในเกมมีหลายคุณลักษณะการเก็บข้อมูลในรูปแบบ Key: Value ช่วยให้เรียกดูและแก้ไขค่าต่าง ๆ ได้อย่างรวดเร็ว

# %% [markdown]
# How could a dictionary represent data about a product in an online store? (e.g., product details by ID)

# %% [markdown]
# Ans.เพราะสินค้าแต่ละชิ้นมี Product ID เฉพาะ การใช้ ID ค้นหาและจัดการข้อมูลสินค้าชิ้นนั้น ๆ ได้รวดเร็ว

# %% [markdown]
# When would a set be useful in managing user permissions or tags? (e.g., unique roles, unique hashtags)

# %% [markdown]
# Ans.เพราะ Set มีคุณสมบัติเด่นคือ ไม่เก็บข้อมูลที่ซ้ำกัน เหมาะกับข้อมูลที่ไม่จำเป็นต้องมีลำดับ แต่ต้องป้องกันการสวมสิทธิ์หรือใส่แท็กซ้ำกัน

# %% [markdown]
# Can you think of a scenario where you'd need to quickly check if an item exists in a large collection without caring about its order? (e.g., blocked IP addresses, unique visitors)

# %% [markdown]
# Ans.เพราะ Set ถูกออกแบบมาเพื่อการตรวจสอบว่า "มีข้อมูลนี้อยู่ในระบบหรือไม่"
# ได้อย่างรวดเร็วเป็นพิเศษ โดยใช้ความเร็วคงที่ซึ่งเร็วกว่า Listมาก เพราะ List ต้องไล่ดูทีละตัวตั้งแต่ต้นจนจบ ทำให้เหมาะกับระบบที่ต้องเช็กข้อมูลปริมาณมหาศาลโดยไม่สนใจลำดับ
