# %%
count = int(input("Enter a starting number for countdown: "))
while count >= 0:
    print(count)
    count -= 1

print("Blast off!")
# Out:
# Enter a starting number for countdown: 8
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# 0
# Blast off!

# %%
secret_number = 42
attempts = 5
attempts_taken = 0

print("Welcome to the Guessing Game! You have 5 attempts.")

while True:
    guess = int(input("Guess the secret number: "))
    attempts_taken += 1

    if guess < secret_number:
        print("Too low! Try again.")
    elif guess > secret_number:
        print("Too high! Try again.")
    else:
        print(f"Congratulations! You guessed it in {attempts_taken} attempts!")
        break

    if attempts_taken == attempts:
        print(f"Game over! You've run out of attempts. The secret number was {secret_number}.")
        break
# Out:
# Welcome to the Guessing Game! You have 5 attempts.
# Guess the secret number: 42
# Congratulations! You guessed it in 1 attempts!
