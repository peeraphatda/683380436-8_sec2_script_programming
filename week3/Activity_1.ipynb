# %%
counter = 0
while counter < 5:
    print(counter)
    counter += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for char in "hello":
    if char == 'l':
        print(char)
        print("Found 'l', stopping!")
        break
    print(char)
# Out:
# h
# e
# l
# Found 'l', stopping!
